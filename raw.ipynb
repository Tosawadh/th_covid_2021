# %% [markdown]
# ## th_covid_2021 (Raw Data)

# %%
import pandas as pd
import seaborn as sns
print(f'pandas version: {pd.__version__}')
print(f'seaborn version: {sns.__version__}')
# This code was ran in Python 3.9.7
# Out:
# pandas version: 1.3.4
# seaborn version: 0.11.2

# %% [markdown]
# ## 2021 monthly cases by country

# %%
dfs1=pd.read_html('https://en.wikipedia.org/wiki/COVID-19_pandemic_cases',header=0)
dfs1[4]
# Out:
#                           Date         First case       Jan 1        Feb 1  \
# 0                          NaN                NaN         NaN          NaN
# 1                        World                NaN  81963694.0  102593717.0
# 2               Days to double                NaN        74.0         80.0
# 3    Countries and territories                NaN       222.0        223.0
# 4                          USA   January 23, 2020  19346790.0   25817939.0
# ..                         ...                ...         ...          ...
# 225                      Palau    August 23, 2021         0.0          0.0
# 226                    Vanuatu  November 11, 2020         1.0          1.0
# 227           Marshall Islands   October 28, 2020         4.0          4.0
# 228                      Samoa   January 20, 2021         0.0          2.0
# 229                      Tonga   October 30, 2021         0.0          0.0
#
# ...

# %% [markdown]
# ## Population Count by country

# %%
dfs2=pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population',header=0)
dfs2[0]
# Out:
#     Rank                 Country / Dependency    Region  Population  \
# 0      –                                world     World  7931119000
# 1      1                                China      Asia  1412600000
# 2      2                                India      Asia  1388235200
# 3      3                        United States  Americas   333253809
# 4      4                         Indonesia[b]      Asia   271350000
# ..   ...                                  ...       ...         ...
# 237    –                   Niue (New Zealand)   Oceania        1549
# 238    –                Tokelau (New Zealand)   Oceania        1501
# 239  195                         Vatican City    Europe         825
# 240    –  Cocos (Keeling) Islands (Australia)   Oceania         573
# 241    –    Pitcairn Islands (United Kingdom)   Oceania          40
#
#      % of world         Date Source (official or from the United Nations)  \
# 0           NaN  19 Feb 2022                             UN projection[1]
# ...
